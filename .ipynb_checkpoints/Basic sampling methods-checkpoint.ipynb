# %%
from sklearn.utils import resample
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd
from collections import Counter
sns.set()

# %%
def plot_data(X, y,alpha=0.5):
    plt.scatter(X[y == 0, 0], X[y == 0, 1], label="Class #0", alpha=alpha, linewidth=0.15,c="blue")
    plt.scatter(X[y == 1, 0], X[y == 1, 1], label="Class #1", alpha=alpha, linewidth=0.15, c='orange')
    plt.legend()
    return plt.show()

# %% [markdown]
# ## Creating a Dataset.
# - Data is noise free.
# - 5% positive class only
# - minimal sub-classes
# - 2 features

# %%
X, y = make_classification(n_samples=500,n_features=2,n_classes=2,n_clusters_per_class=1,
                           weights=[0.95],n_redundant=0,random_state=0)

# %%
counter = Counter(y)

# %%
# visualizing the original data
plt.figure(figsize=(14,7)) 
plt.title("Original Data distribution")
plot_data(X,y,alpha=0.8)

# %%
X0 = pd.Series(X[:,0])
X1 = pd.Series(X[:,1])
y = pd.Series(y)

# %%
dataset = pd.concat([X0,X1,y],axis=1)
dataset.head()
# Out:
#           0         1  2
# 0  0.915159 -1.231582  0
# 1  0.129518 -2.208434  0
# 2 -1.612913 -4.550778  0
# 3  0.602314 -1.196823  0
# 4  1.352625 -0.465299  0

# %%
dataset.columns = ["X0","X1","Class"]

# %%
dataset.Class.value_counts()
# Out:
# 0    473
# 1     27
# Name: Class, dtype: int64

# %%
majority = dataset[dataset.Class==0]
minority = dataset[dataset.Class==1]

# %%
minority.head()
# Out:
#           X0        X1  Class
# 10  0.004737  1.042163      1
# 23  0.261783  0.463199      1
# 39  1.338179  1.253558      1
# 48 -0.287579 -2.589656      1
# 54  0.260580  0.203486      1

# %% [markdown]
# #### Upsampling the minority class.
# - Make the minority class equal to the majority class by resampling with replacement aka duplicating instances.
# - Each example will be occuring multiple times in the dataset.
# - The up-sampling is random, therefore, not all duplicated examples with have exact amount.

# %%
# Upsample minority class
minority_upsampling = resample(minority, 
                                 replace=True,     # we have to use replacement since we are upsampling
                                 n_samples=len(majority),    # as much as majority
                                 random_state=0)

# %%
upsampled_minority_df = pd.concat([majority,minority_upsampling])

# %%
upsampled_minority_df.Class.value_counts()
# Out:
# 1    473
# 0    473
# Name: Class, dtype: int64

# %%
upsampled_minority_df.tail()
# Out:
#            X0        X1  Class
# 347  2.781350 -0.768438      1
# 242 -0.117243  0.998559      1
# 410  0.927538  0.535256      1
# 458  0.384516  0.109259      1
# 54   0.260580  0.203486      1

# %%
X_upsampled = np.array(pd.concat([upsampled_minority_df['X0'],upsampled_minority_df['X1']],axis=1))

# %%
counter_upsampled = Counter(upsampled_minority_df.Class)

# %% [markdown]
# ##### Plotting the data.
# - Since we did an upsampling, the same point will have multiple duplicates.
# - We lower the alpha in the scatter plot to see the effect or density of colors for the new dataset.
# - Duplicated points will have a stronger color/density than non duplicates.

# %%
points_mark_size = upsampled_minority_df[upsampled_minority_df.duplicated(["X0","X1"])].\
groupby(["X0","X1"]).size().\
reset_index(name='Duplicates')

# %%
plt.figure(figsize=(14,7)) 
plt.scatter(upsampled_minority_df[upsampled_minority_df["Class"]==0]["X0"],
           upsampled_minority_df[upsampled_minority_df["Class"]==0]["X1"],
           alpha = 0.3,color="blue", label = 0)
plt.scatter(points_mark_size["X0"],points_mark_size["X1"],s=points_mark_size["Duplicates"]*8, color="orange",label=1)
plt.legend()
plt.title("Random Upsampling points")
plt.show()

# %%
plt.figure(figsize=(10,5)) 
for label, _ in counter_upsampled.items():
    row_ix = np.where(upsampled_minority_df.Class == label)[0]
    plt.hist2d(X_upsampled[row_ix,0],X_upsampled[row_ix,1],(50,50),cmap=plt.cm.jet)
    plt.colorbar()
# show the figure
plt.title("Upsampled data Density distribution")
plt.show()

# %%
dups = upsampled_minority_df.pivot_table(index = ['X0','X1'], aggfunc ='size') 
above_1 = dups[dups>1]

# %%
counts_df = pd.DataFrame(above_1,columns=["Count"])

# %%
couples_list = ['C{}'.format(i) for i in range(len(counts_df))]

# %%
counts_df['Couple'] = couples_list

# %%
plt.figure(figsize=(20,10)) 
sns.barplot(x=counts_df.Couple,y=counts_df.Count)
plt.title("Duplicate counts for each couple(Upsampling)")
plt.show()

# %% [markdown]
# #### Downsampling the majority class.
# - We will pick random points from the data to draw them.
# - Data could be highly unrepresentative of the original distribution.

# %%
majority_downsampling = resample(majority, 
                                 replace=False,     # unique samples
                                 n_samples=len(minority),    # as much as minority
                                 random_state=0)

# %%
downsampled_majority_df = pd.concat([majority_downsampling,minority])
downsampled_majority_df.Class.value_counts()
# Out:
# 1    27
# 0    27
# Name: Class, dtype: int64

# %%
X_downsampled = np.array(pd.concat([downsampled_majority_df['X0'],downsampled_majority_df['X1']],axis=1))

# %%
counter_downsampled = Counter(downsampled_majority_df.Class)

# %%
plt.figure(figsize=(14,7)) 
# show the figure
plt.title("Downsampled Majority group")
plot_data(downsampled_majority_df[["X0","X1"]].to_numpy(),downsampled_majority_df.Class,alpha=1)

# %%
# !pip install imblearn --user

# %% [markdown]
# ### Avanced sampling methods.
# - Synthetic Sampling (SMOTE)
# - Adaptive Synthetic sampling.
# - We are going to try multiple algorithms and highlight the difference between them.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import BorderlineSMOTE,SVMSMOTE,ADASYN,SMOTENC,RandomOverSampler

# %%
# regular smote method; all the points will be resampled with neighbors.
def perform_SMOTE(neighbors=5):
    method = SMOTE(random_state=0,k_neighbors=neighbors)

    # Create the resampled feature set
    X_resampled, y_resampled = method.fit_sample(X, y)
    print("Data Distribution is: ",Counter(y_resampled))
    # Plot the resampled data
    return plot_data(X_resampled, y_resampled)

# %% [markdown]
# #### SMOTE.
# - creating artificial data using the surrouding similar points.
# - Changing the K in K-Nearest points for the algorithm can produce different results.
#     - For example choosing K = 3 we see that the synthetic points are tighter (closer to each others).
#     - For K = 10 the coverage of synthetic data points gets wider.
#     - Desntiy for higher K is lower, however, not recommended to get too high with neighbors since it is possible to create an un representative dataset.
# - Difference between SMOTE and random over-sampling is that new fake data similar to the original one is generated.
#
# \begin{align}
# x_{new} & = \delta (\dot{x}_i-x_i) + x_i \\
# \end{align}

# %%
for k in [3,5,8,10]:
    plt.title("SMOTE {} Neighbors".format(k))
    perform_SMOTE(k)
# Out:
# Data Distribution is:  Counter({0: 473, 1: 473})
# Data Distribution is:  Counter({0: 473, 1: 473})
# Data Distribution is:  Counter({0: 473, 1: 473})
# Data Distribution is:  Counter({0: 473, 1: 473})

# %% [markdown]
# #### BorderLine-SMOTE.
# - Improved version of SMOTE.
# - The points that are near the "DANGER" zone are the ones resampled.
# - DANGER zone is defined by the data points from the minority class that are near the majority class (Hard points to classify).
# - If a datapoint from the minority class is surrounded by M - majority class neighbors then this point is considered as noise and won't be synthesized.
# - In other words, easy to classify points are not resampled, noisy considered points are not resampled.
#     - higher neighbors can lead to data disturbance and unrepresentitiveness
#     - higher neighbors can lead to disturb the reason behind the usage of Borderline
# - BorderLine2 from an observational point seems to create data that is relatively closer to the cluster of the second data class. Which means, that it tries to focus on the bordering line between the class to learn the hardest points possible.

# %%
def perform_borderlineSMOTE(neighbors=5,kind='borderline-1'):
    # initiate model
    method = BorderlineSMOTE(random_state=0,k_neighbors=neighbors,kind=kind)
    # Create the resampled feature set
    X_resampled, y_resampled = method.fit_sample(X, y)
    print("Data Distribution is: ",Counter(y_resampled))
    # Plot the resampled data
    return plot_data(X_resampled, y_resampled)


for k in [3,5,8,10]:
    plt.title("BorderlineSMOTE {} Neighbors".format(k))
    perform_borderlineSMOTE(k)
for k in [3,5,8,10]:
    plt.title("BorderlineSMOTE(2) {} Neighbors".format(k))
    perform_borderlineSMOTE(k,kind='borderline-2')
# Out:
# Data Distribution is:  Counter({0: 473, 1: 473})
# Data Distribution is:  Counter({0: 473, 1: 473})
# Data Distribution is:  Counter({0: 473, 1: 473})
# Data Distribution is:  Counter({0: 473, 1: 473})
# Data Distribution is:  Counter({0: 473, 1: 472})
# Data Distribution is:  Counter({0: 473, 1: 472})
# Data Distribution is:  Counter({0: 473, 1: 472})
# Data Distribution is:  Counter({0: 473, 1: 472})

# %% [markdown]
# #### ADASYN.
# - the newly generated data points will be according to the distribution of points.
# - Points will have a more equal distribution compared to previous algorithms.

# %%
def perform_ADASYN(neighbors=5):
    # initiate model
    method = ADASYN(random_state=0,n_neighbors=neighbors)
    # Create the resampled feature set
    X_resampled, y_resampled = method.fit_sample(X, y)
    print("Data Distribution is: ",Counter(y_resampled))
    # Plot the resampled data
    return plot_data(X_resampled, y_resampled)

for k in [3,5,8,10]:
    plt.title("Adaptive Synthetic sampling {} Neighbors".format(k))
    perform_ADASYN(k)
# Out:
# Data Distribution is:  Counter({0: 473, 1: 472})
# Data Distribution is:  Counter({0: 473, 1: 472})
# Data Distribution is:  Counter({1: 477, 0: 473})
# Data Distribution is:  Counter({0: 473, 1: 472})

# %% [markdown]
# ### Creating a Model.
# - We are going to create a logistic regression model on the basic data and see if would produce good results.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
# np.random.seed(0)

# %%
from imblearn.pipeline import Pipeline

# %%
X_new, y_new = make_classification(n_samples=2000,n_features=2,n_classes=2,n_clusters_per_class=1,
                           weights=[0.97],n_redundant=0,random_state=11)

# %%
plot_data(X_new,y_new)

# %% [markdown]
# ##### Baseline Model.

# %%
X_train,X_test,y_train,y_test = train_test_split(X_new,y_new,test_size=0.25,stratify = y_new,random_state=0)

# %%
# Initiating and training the model.
model = LogisticRegression(random_state=0)
# train and fit
model.fit(X_train,y_train)

# model predictions
predicted = model.predict(X_test)
# Print the classifcation report and confusion matrix
print('Classification report:\n', classification_report(y_test, predicted))

conf_mat = confusion_matrix(y_true=y_test, y_pred=predicted)
sns.heatmap(pd.DataFrame(conf_mat,index=["False","True"],columns=["False","True"]),annot=True,fmt='d')
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       483
#            1       0.75      0.18      0.29        17
#
#     accuracy                           0.97       500
#    macro avg       0.86      0.59      0.64       500
# weighted avg       0.96      0.97      0.96       500

# %%
from sklearn.metrics import precision_score, recall_score,f1_score

# %%
## Create the results multiple times for experimental purposes.
dictionary_metrics = {"Accuracy":[],"Precision":[],"Recall":[],"F1-Score":[]}
for i in range(15):
    X_train,X_test,y_train,y_test = train_test_split(X_new,y_new,test_size=0.30,stratify = y_new,shuffle=True)
    # Initiating and training the model.
    model = LogisticRegression()
    # train and fit
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)
    dictionary_metrics["Accuracy"].append(model.score(X_test,y_test))
    dictionary_metrics["Precision"].append(precision_score(y_test,predictions))
    dictionary_metrics["Recall"].append(recall_score(y_test,predictions))
    dictionary_metrics["F1-Score"].append(f1_score(y_test,predictions))
results_summary = pd.DataFrame(dictionary_metrics)
results_summary.loc['mean'] = results_summary.mean()
results_summary
# Out:
#       Accuracy  Precision    Recall  F1-Score
# 0     0.965000   0.500000  0.047619  0.086957
# 1     0.970000   1.000000  0.142857  0.250000
# 2     0.965000   0.500000  0.095238  0.160000
# 3     0.966667   0.600000  0.142857  0.230769
# 4     0.966667   0.545455  0.285714  0.375000
# 5     0.965000   0.500000  0.238095  0.322581
# 6     0.970000   0.800000  0.190476  0.307692
# 7     0.963333   0.400000  0.095238  0.153846
# 8     0.970000   1.000000  0.142857  0.250000
# 9     0.965000   0.500000  0.095238  0.160000
# 10    0.971667   0.833333  0.238095  0.370370
# 11    0.963333   0.333333  0.047619  0.083333
# 12    0.965000   0.500000  0.047619  0.086957
# 13    0.966667   0.600000  0.142857  0.230769
# 14    0.965000   0.500000  0.142857  0.222222
# mean  0.966556   0.607475  0.139683  0.219366

# %% [markdown]
# ##### Logistic Regression + Equalized Upsampling.
# - In the following we try multiple upsampling algorithms with a logistic regression model and we check the different metrics.
# - Equal upsampling is not 'the' optimal upsampling, however, we are going to use it.
# - Later work, is the use of Upsampling and downsampling methods. on a similar model.

# %%
def draw_confusion(confusion_matrix,model_name):
    sns.heatmap(pd.DataFrame(confusion_matrix,index=["Act.False","Act.True"],columns=["Pred.False","Pred.True"]),annot=True,fmt='d')
    plt.title("Confusion Matrix of {}".format(model_name))
    plt.show()
    
def imb_pipeline(model_name,model_instantiation,classifier_name="Logistic Regression",classifier=LogisticRegression(random_state=0),X=X_train,y=y_train,x_test=X_test,y_true = y_test):
    # pipeline containing the resampling method and the LogReg
    pipeline = Pipeline([(model_name,model_instantiation),(classifier_name,classifier)])
    # training and fitting the model
    pipeline.fit(X,y)
    # predicting on the test set
    predicted_pipeline = pipeline.predict(x_test)
    # report
    print('Classification report for {}:\n'.format(model_name), classification_report(y_true, predicted_pipeline))
    #confus matrix
    conf_mat = confusion_matrix(y_true, predicted_pipeline)
    draw_confusion(conf_mat,model_name)

# %%
# # GENERAL FORM
dictionary_model = {"Random":RandomOverSampler(random_state=0),
                    "SMOTE":SMOTE(random_state=0),
                    "Border":BorderlineSMOTE(random_state=0),
                    "ADAPT":ADASYN(random_state=0)}

for model, model_instantiation in dictionary_model.items():
    # resampling the data
    X_oversampled,y_oversampled = model_instantiation.fit_sample(X_train,y_train)
    # plotting the oversampled data
    plt.title("Oversampling using {}".format(model))
    plot_data(X_oversampled,y_oversampled)
    # Pipeline run.
    imb_pipeline(model,model_instantiation)
# Out:
# Classification report for Random:
#                precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91       487
#            1       0.11      0.77      0.20        13
#
#     accuracy                           0.84       500
#    macro avg       0.55      0.81      0.56       500
# weighted avg       0.97      0.84      0.89       500
# Classification report for SMOTE:
#                precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91       487
#            1       0.11      0.77      0.20        13
#
#     accuracy                           0.84       500
#    macro avg       0.55      0.81      0.56       500
# weighted avg       0.97      0.84      0.89       500
# Classification report for Border:
#                precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95       487
#            1       0.17      0.69      0.28        13
#
#     accuracy                           0.91       500
#    macro avg       0.58      0.80      0.61       500
# weighted avg       0.97      0.91      0.93       500
# Classification report for ADAPT:
#                precision    recall  f1-score   support
#
#            0       0.99      0.78      0.87       487
#            1       0.09      0.77      0.16        13
#
#     accuracy                           0.78       500
#    macro avg       0.54      0.78      0.51       500
# weighted avg       0.97      0.78      0.86       500

# %% [markdown]
# ##### Logistic Regression + Upsampling-Data Cleaning (SMOTE+ENN, Tomek Links+SMOTE).
# - To avoid having overlapping/similar synthetic data, we could use SMOTE with downsampling techniques that will eliminate certain data points to get a cleaner synthetic dataset.

# %%
from imblearn.combine import SMOTEENN,SMOTETomek

# %%
smotetomek = SMOTETomek(random_state=0)
X_smotek, y_smotek = smotetomek.fit_resample(X_train, y_train)
plt.title("SMOTE + Tomek Links")
plot_data(X_smotek,y_smotek)
imb_pipeline("SMOTE-TOMEK",smotetomek)
print("The final amount of data:",Counter(y_smotek))
# Out:
# Classification report for SMOTE-TOMEK:
#                precision    recall  f1-score   support
#
#            0       0.99      0.85      0.91       487
#            1       0.12      0.77      0.20        13
#
#     accuracy                           0.84       500
#    macro avg       0.56      0.81      0.56       500
# weighted avg       0.97      0.84      0.90       500
# The final amount of data: Counter({0: 1350, 1: 1350})

# %% [markdown]
# - We can see that combining smote+ tomek links reduced the number of samples to 1350 for both classes vs 1450 in the previous algorithms.

# %%
smoteENN = SMOTEENN(random_state=0)
X_smotenn, y_smotenn = smoteENN.fit_resample(X_train, y_train)
plt.title("SMOTE Edited nearest neighbor ")
plot_data(X_smotenn,y_smotenn)
imb_pipeline("SMOTEENN",smoteENN)
print("Resampled data count:",Counter(y_smotenn))
# Out:
# Classification report for SMOTEENN:
#                precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93       487
#            1       0.15      0.77      0.25        13
#
#     accuracy                           0.88       500
#    macro avg       0.57      0.83      0.59       500
# weighted avg       0.97      0.88      0.92       500
# Resampled data count: Counter({1: 1130, 0: 1073})

# %% [markdown]
# ##### Ensemble methods.
# - EasyEnsemble, is an informed undersampling method that will create multiple subsets/bags of the majority class using RUnS.
# - BalanceCascade uses iteratively informed choices of majority class subsamples equal to the size of the minority class.
# - NearMiss

# %% [markdown]
# # 14-10-2020.
# - Step One:
#     - Create a higher dimensional dataset
#     - Oversampling test data and simulate the results
# - Step two:
#     - Real dataset UCI
#     - Downsampling the majority class
#     - Upsample and test
# - Step three:
#     - Choosing a metric for reporting and trying AUC P-R curves.

# %%
from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import plot_roc_curve

# %%
def higher_dimensional_imclass(samples=2500,features=4,weights=[0.95]):
    X,y = make_classification(n_samples=samples,n_features=4,n_classes=2,n_clusters_per_class=1,
                              weights=[0.95],n_redundant=0,random_state=0)
    # plotting 2D of the data 
    plot_data(X,y)
    
    return X,y

# %%
X_3d,y_3d = higher_dimensional_imclass()

# %%
def to_df(X,y):
    X_df = pd.DataFrame(X)
    y_series = pd.Series(y)
    columns_1 = ['X_{}'.format(i) for i in range(X.shape[1])]
    columns_1.append("Class")
    dataframe = pd.DataFrame(pd.concat([X_df,y_series],axis=1))
    dataframe.columns=columns_1
    return dataframe

# %%
def logreg_model(X_train,X_test,y_train,y_test):
    model = LogisticRegression(random_state=0)
    model.fit(X_train,y_train)
    predicted_model = model.predict(X_test)
    print('Classification report for log:\n', classification_report(y_test, predicted_model))
    #confus matrix
    conf_mat = confusion_matrix(y_test, predicted_model)
    draw_confusion(conf_mat,'logreg')
    plot_precision_recall_curve(model,X_test,y_test)
    plt.title("P-R Curve")
    plt.show()
    plot_roc_curve(model,X_test,y_test)
    plt.title("ROC Curve")
    plt.show()
    return model

# %%
# transforming data into dataframe
data_3d = to_df(X_3d,y_3d)

# %% [markdown]
# #### Baseline Model (4 features data).

# %%
# creating train test sets and training our first model as a baseline for the new data
X_train30, X_test30, y_train30, y_test30 = train_test_split(data_3d.iloc[:,:4],data_3d.iloc[:,-1],
                                                            test_size=0.25,random_state=0)
print(Counter(y_train30))
logreg_model(X_train30, X_test30, y_train30, y_test30)
# Out:
# Counter({0: 1766, 1: 109})
# Classification report for log:
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       592
#            1       0.78      0.55      0.64        33
#
#     accuracy                           0.97       625
#    macro avg       0.88      0.77      0.81       625
# weighted avg       0.96      0.97      0.97       625
# LogisticRegression(random_state=0)

# %% [markdown]
# #### Oversampling the Minority class.
# - First we oversample using a method
# - Test the overall sampling metrics
# - Test on original datapoints
# - Test on fake simulated datapoints

# %%
SMOTE_mod = SMOTE(random_state=0)
# sampling the training data of the previous model
X_3d_sampled, y_3d_sampled = SMOTE_mod.fit_sample(X_train30,y_train30)
Counter(y_3d_sampled)
# Out:
# Counter({0: 1766, 1: 1766})

# %%
# training on SMOTE-sampled data and testing on ORIGINAL DATA
logreg_model(X_3d_sampled, X_test30, y_3d_sampled, y_test30)
# Out:
# Classification report for log:
#                precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94       592
#            1       0.29      0.79      0.42        33
#
#     accuracy                           0.89       625
#    macro avg       0.64      0.84      0.68       625
# weighted avg       0.95      0.89      0.91       625
# LogisticRegression(random_state=0)

# %%
X_3d_sampled_test, y_3d_sampled_test = SMOTE_mod.fit_sample(X_test30,y_test30)

# %%
# training on sampled data and testing on SAMPLED TESTSET (fake + original data)
logreg_model(X_3d_sampled, X_3d_sampled_test, y_3d_sampled, y_3d_sampled_test)
# Out:
# Classification report for log:
#                precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       592
#            1       0.88      0.76      0.81       592
#
#     accuracy                           0.83      1184
#    macro avg       0.83      0.83      0.82      1184
# weighted avg       0.83      0.83      0.82      1184
# LogisticRegression(random_state=0)

# %% [markdown]
# ##### Analysis of preliminary results.
# - Testing on fake dataset, if the fake data is representative would generate similar Recall results.
# - However, since more TP will be classified due to the fake data, the precision of the test set with fake data will increase.
# - Similarly the precision of the negative class will decrease, since some fake data will get misclassified.
# - TP will increase and the FN will increase with more fake data.

# %% [markdown]
# ## 21-10-2020
# - Simulate a bigger data to have a bigger pool of positive attributes.
#     - Split data to still have test data from the original distribution
# - Research on the metrics.

# %%
X_big, y_big = higher_dimensional_imclass(samples=10000)
X_A, X_B, y_A, y_B = train_test_split(X_big,y_big,stratify=y_big,random_state=0,test_size = 0.5)

# %%
plot_data(X_A,y_A)
plot_data(X_B,y_B)

# %%
X_train_A, X_test_A, y_train_A, y_test_A = train_test_split(X_A,y_A,test_size = 0.25)

# %%
logreg_model(X_train_A, X_test_A, y_train_A, y_test_A)
# Out:
# Classification report for log:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1186
#            1       0.97      0.56      0.71        64
#
#     accuracy                           0.98      1250
#    macro avg       0.97      0.78      0.85      1250
# weighted avg       0.98      0.98      0.97      1250
# LogisticRegression(random_state=0)

# %%
dictionary_model = {"SMOTE":SMOTE(random_state=0), "Border":BorderlineSMOTE(random_state=0)}

for model, model_instantiation in dictionary_model.items():
    # resampling the data
    X_oversampled,y_oversampled = model_instantiation.fit_sample(X_train_A,y_train_A)
    # plotting the oversampled data
    plt.title("Oversampling using {}".format(model))
    plot_data(X_oversampled,y_oversampled)
    # Pipeline run.
    logreg_model(X_oversampled, X_test_A, y_oversampled, y_test_A)
    print("\n\n\n\n\n")
# Out:
# Classification report for log:
#                precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95      1186
#            1       0.32      0.67      0.43        64
#
#     accuracy                           0.91      1250
#    macro avg       0.65      0.80      0.69      1250
# weighted avg       0.95      0.91      0.92      1250
# Classification report for log:
#                precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93      1186
#            1       0.24      0.69      0.35        64
#
#     accuracy                           0.87      1250
#    macro avg       0.61      0.78      0.64      1250
# weighted avg       0.94      0.87      0.90      1250

# %%
# oversampling the minority using SMOTE and testing on the left out distribution.
smote = SMOTE(random_state=0)
X_oversampled_A, y_oversampled_A = smote.fit_sample(X_train_A,y_train_A)
logreg_model(X_oversampled_A,X_B,y_oversampled_A,y_B)
# Out:
# Classification report for log:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      4727
#            1       0.40      0.79      0.53       273
#
#     accuracy                           0.92      5000
#    macro avg       0.69      0.86      0.75      5000
# weighted avg       0.96      0.92      0.94      5000
# LogisticRegression(random_state=0)

# %% [markdown]
# ### Metrics discussion.
# ##### Class Predictions (one threshold used to get the results).
# - <u>Accuracy or Error</u>: Bad, imbalanced data yields high accuracy due to the model learning the negative (majority class) easily.
#  - $\frac{Correct}{Total}$
# - <u>MCC</u>: Similar to the Pearson correlation formula, it regroups all the CM information (-1 all is wrong, 0 no better than random, 1 all is correct).
# - <u>F-Measure / F-1 / F-B</u>: harmonic mean of precision and recall. Shows the tradeoff between the correctness and the predictive power of the model (Very good if FP, in other words, if the FP are costly).
#     - $\frac{2.Precision.Recall}{Precision+Recall}$
# - <u>G-Measure</u>: geometric mean of Precision and recall.
#     - $ \sqrt{Precision * Recall} $
#
#     - <u>G-Mean</u>:
#         - $ \sqrt{TPR + TNR} $
#     - <u>Balanced Accuracy</u>:
#         - $ \frac{TPR + TNR}{2} $
#
# ##### Scoring Predictions.
# - <u>ROC Curve</u> : TPR vs FPR. We can understand more how much False positives we want to tolerate in our model while trying to maximize our Correctness (for the positive class).
#     - Best be used when having different models and we compare their predictive power.
#     - For a similar model, we can extract the threshold that we find optimal.
# - <u>Pre-Re Curve</u>: more focus on the positive class. Trade-off between the correctness and the positive predictive value of the classifier.
#
# ##### Notes.
# - 'It should be keep in mind that there is no universally performance measure, as they consider different and often conflicting criteria.' - Learning from Imbalanced Data Sets.
# - 'The choice of adequate performance measure is domain dependent, and it should take into account the adequate objectives in the comparison.'
